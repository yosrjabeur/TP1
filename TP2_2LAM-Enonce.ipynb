# %% [markdown]
# <p>Nom et prénom: <b>Ben Jabeur Yosr</b></p>
# <p>Classe:<b> 2LM3 TP2</b></p>
# <p>ISITCom Hammam Sousse en <b>2021/2022</b></p>

# %% [markdown]
# # Simulation du jeux de LIDO simplifié

# %% [markdown]
# ## Principe
# On considére un jeux de Lido simple:
# on dispose d'un un seul pion.
#
# - Etape 0 :
# Le pion doit sort de sa prison lorsqu'on obtient un 6.
#
# - Etape 1 :
# Le pion doit atteindre exactement une position cible situé à N pas de distance de sa prison
#
# Soit $X_n$ la variable aléatoire qui represente le nombre de coup nécéssaire pour atteindre la positions cible.
#
# **Objectif 1** : Simuler le jeux
#
# **Objectif 2** : Calculer une estimation de l'éspérance mathématique de $X_n$ en utilisant `python`
#
# **Objéctif 3** : Observer la variation de $\mathbb{E}(X_n)$ en fonction de $n$
#
# <img src="LIDO.png">

# %%
import numpy as np

# %% [markdown]
# ### Simulation du lancé de dé

# %%
def Roll():
    return int(np.random.choice(range(1,7),1))

# %%
Roll()
# Out:
# 2

# %% [markdown]
# ### Compléter le code et commenter

# %%
A=0
NA=0
S=10
c=0
## sortir du prison ##
temp=Roll()
NA+=1
while(temp!=6):
    temp=Roll()
    NA+=1
    print(NA,temp)
A=1
print('sortir aprés {} coups '.format(NA))
## parcours vers la cible
while(A!=S):
    temp=Roll()
    if (temp+A<S):
        A=A+temp
        NA+=1
        print(NA,temp,A)
    elif(temp+A>S):
        NA+=print(NA,temp,A)
    else:
        A=S
        NA+=1
        print(NA,temp,A)
        break
# Out:
# sortir aprés 1 coups
# 2 2 3
# 3 6 9
# 4 5 9
# 5 2 9
# 6 1 10

# %% [markdown]
# ### Simulation
# Ecrire une foction `sim` qui simule le jeux et qui prend comme variable le nombre de pas $n$ nécessazire pour atteindre la cible

# %%
def sim(S):
    NA=0
    S=10
    c=0
## sortir du prison ##
    temp=Roll()
    NA+=1
    while(temp!=6):
        temp=Roll()
        NA+=1
    A=1
    print("sortir aprés {} coups ".format(NA))
## parcours vers la cible
    while(A!=S):
        temp=Roll()
        if (temp+A<S):
            A=A+temp
      #  NA+=1
        elif(temp+A>S):
            continue
        else:
            A=S
    return NA 
#le nombre de cout necessaire pour atteindre la position cible

# %%
#simulation 10000 fois n=30
L=[sim(30) for i in range(10000)]
Moy=sim(L)/10000
print('stimation de la moyenne de X_30={}'.format(Moy))
# Out:
# sortir aprés 4 coups
# sortir aprés 2 coups
# sortir aprés 1 coups
# sortir aprés 5 coups
# sortir aprés 2 coups
# sortir aprés 8 coups
# sortir aprés 9 coups
# sortir aprés 3 coups
# sortir aprés 3 coups
# sortir aprés 4 coups
# sortir aprés 11 coups
# sortir aprés 1 coups
# sortir aprés 4 coups
# sortir aprés 1 coups
# sortir aprés 7 coups
# sortir aprés 1 coups
# sortir aprés 2 coups
# sortir aprés 11 coups
# sortir aprés 3 coups
# sortir aprés 7 coups
# sortir aprés 2 coups
# sortir aprés 8 coups
# sortir aprés 8 coups
# sortir aprés 3 coups
# sortir aprés 7 coups
# sortir aprés 13 coups
# sortir aprés 6 coups
# sortir aprés 8 coups
# sortir aprés 5 coups
# sortir aprés 9 coups
# sortir aprés 3 coups
# sortir aprés 1 coups
# sortir aprés 2 coups
# sortir aprés 4 coups
# sortir aprés 1 coups
# sortir aprés 6 coups
# sortir aprés 3 coups
# sortir aprés 2 coups
# sortir aprés 2 coups
# sortir aprés 5 coups
# sortir aprés 1 coups
# sortir aprés 20 coups
# sortir aprés 2 coups
# ...

# %% [markdown]
# ### Simulation de $10^5$  scénario

# %%
Freq=np.fromiter((sim(20) for i in range(10**5)),dtype=int)

# %%
ESP=Freq.sum()/10**5
# Out:
# 16.17253

# %%
x=list(range(10,20))
x
y=[sum([sim(u) for i in range(10000)])/10000 for u in x]
# Out:
# sortir aprés 14 coups
# sortir aprés 2 coups
# sortir aprés 6 coups
# sortir aprés 2 coups
# sortir aprés 1 coups
# sortir aprés 2 coups
# sortir aprés 6 coups
# sortir aprés 4 coups
# sortir aprés 4 coups
# sortir aprés 4 coups
# sortir aprés 4 coups
# sortir aprés 6 coups
# sortir aprés 1 coups
# sortir aprés 14 coups
# sortir aprés 10 coups
# sortir aprés 12 coups
# sortir aprés 1 coups
# sortir aprés 1 coups
# sortir aprés 11 coups
# sortir aprés 7 coups
# sortir aprés 13 coups
# sortir aprés 2 coups
# sortir aprés 5 coups
# sortir aprés 4 coups
# sortir aprés 3 coups
# sortir aprés 3 coups
# sortir aprés 3 coups
# sortir aprés 5 coups
# sortir aprés 2 coups
# sortir aprés 3 coups
# sortir aprés 6 coups
# sortir aprés 8 coups
# sortir aprés 7 coups
# sortir aprés 3 coups
# sortir aprés 4 coups
# sortir aprés 6 coups
# sortir aprés 1 coups
# sortir aprés 3 coups
# sortir aprés 15 coups
# sortir aprés 5 coups
# sortir aprés 5 coups
# sortir aprés 9 coups
# sortir aprés 5 coups
# ...

# %%
y=[np.fromiter((sim(u) for i in range(5*10**4)),dtype=int).sum()/50000 for u in x]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,'*r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-0ec97bd8a37e> in <module>
# ----> 1 plt.plot(x,y,'*r')
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
## scipy donne a et b
from scipy import stats
import numpy as np
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e2c7bccd56a1> in <module>
#       2 from scipy import stats
#       3 import numpy as np
# ----> 4 slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
#
# NameError: name 'x' is not defined

# %%
slope
# valeur de a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c354d8f7e914> in <module>
# ----> 1 slope
#       2 # valeur de a
#
# NameError: name 'slope' is not defined

# %%
intercept
# valeur de b

# %%
yy=[slope *u +intercept fo u in c]

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ##### Dans ce TP on fait la simulation du jeu LUDO avec des simple étapes.
# ###### aprés on calcule l'estimation de l'éspérance avec python puis on a observé la variation:
# aprés l'étude éxprémental on résulte que
#
# a = 0.288715272727254
#
# et
#
# b = 10.443562545454547
#
# alors:
#
#
# $E(X)$ ~= 0.291*n+10.37
